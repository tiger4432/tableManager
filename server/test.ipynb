# %%
from parser import html_topology_parser

# %%
with open('server\ingestion_workspace\inventory_master\err\user(kk980)_web_smart_paste_1781644399980_00f6b51d.html') as f:
    html = f.read()

html
